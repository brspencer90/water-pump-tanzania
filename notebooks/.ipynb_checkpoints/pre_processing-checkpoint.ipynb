# %%
# import modules

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns

from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %qtconsole

# %%
data_raw_dir = 'C:\\Users\\Bryan\\OneDrive\\02 GitHub\\water-pump-tanzania\\data\\raw\\'
data_interim_dir = 'C:\\Users\\Bryan\\OneDrive\\02 GitHub\\water-pump-tanzania\\data\\interim\\'
data_processed_dir = 'C:\\Users\\Bryan\\OneDrive\\02 GitHub\\water-pump-tanzania\\data\\processed\\'
docs_img_dir = 'C:\\Users\\bryan\\OneDrive\\02 GitHub\\water-pump-tanzania\\docs\\img\\'

# %%
df_train_val = pd.read_csv(data_raw_dir + 'training_values.csv')
df_test_val = pd.read_csv(data_raw_dir + 'test_values.csv')
df_train_lab = pd.read_csv(data_raw_dir + 'training_labels.csv')

df_comp_val = pd.read_csv(data_interim_dir + 'comp_data_clean_impv2_geo-corr.csv')
# Out:
# C:\Users\bryan\Anaconda3\envs\geo_code\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_comp_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74250 entries, 0 to 74249
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     74250 non-null  int64
#  1   amount_tsh             74250 non-null  float64
#  2   gps_height             74250 non-null  int64
#  3   installer              74250 non-null  object
#  4   longitude              74250 non-null  float64
#  5   latitude               74250 non-null  float64
#  6   basin                  74250 non-null  object
#  7   region                 74250 non-null  object
#  8   district_code          74250 non-null  int64
#  9   population             74250 non-null  int64
#  10  public_meeting         74250 non-null  int64
#  11  permit                 74250 non-null  int64
#  12  extraction_type_class  74250 non-null  object
#  13  management             74250 non-null  object
#  14  payment_type           74250 non-null  object
#  15  water_quality          74250 non-null  object
#  16  quantity               74250 non-null  object
#  17  source                 74250 non-null  object
#  18  source_class           74250 non-null  object
#  19  waterpoint_type        74250 non-null  object
#  20  pump_age               74250 non-null  float64
#  21  status_group           59400 non-null  object
# dtypes: float64(4), int64(6), object(12)
# memory usage: 12.5+ MB

# %% [markdown]
# Need to encode all object and categorical values.

# %% [markdown]
# ### amount_tsh

# %%
var = 'amount_tsh'

df_comp_val[var].value_counts()
# Out:
# 0.00         52049
# 500.00        3874
# 50.00         3103
# 1000.00       1858
# 20.00         1812
#              ...
# 59.00            1
# 38000.00         1
# 120000.00        1
# 220.00           1
# 0.25             1
# Name: amount_tsh, Length: 102, dtype: int64

# %%
plt.figure()

plt.hist(df_comp_val[df_comp_val['status_group']=='non functional'][var],alpha=0.5,density=True);
plt.hist(df_comp_val[df_comp_val['status_group']=='functional'][var],color='green',alpha=0.5,density=True);
plt.hist(df_comp_val[df_comp_val['status_group']=='functional needs repair'][var],color='red',alpha=0.5,density=True);

# %% [markdown]
# ### gps_height

# %%
var = 'gps_height'
var_red = var+'_reduced'

df_comp_val[var].value_counts()
# Out:
#  0       25649
# -16         71
# -15         69
# -13         68
# -19         65
#          ...
#  2353        1
#  2417        1
#  2545        1
#  2416        1
#  2285        1
# Name: gps_height, Length: 2456, dtype: int64

# %%
plt.figure()

plt.hist(df_comp_val[df_comp_val['status_group']=='non functional'][var],alpha=0.5,density=True);
plt.hist(df_comp_val[df_comp_val['status_group']=='functional'][var],color='green',alpha=0.5,density=True);
plt.hist(df_comp_val[df_comp_val['status_group']=='functional needs repair'][var],color='red',alpha=0.5,density=True);

# %% [markdown]
# ### installer

# %%
var = 'installer'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[8:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# DWE           21751
# unknown        4533
# Government     2282
# RWE            1498
# Commu          1347
# DANIDA         1305
# KKKT           1120
# Hesawa         1070
# Name: installer, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# other         39344
# DWE           21751
# unknown        4533
# Government     2282
# RWE            1498
# Commu          1347
# DANIDA         1305
# KKKT           1120
# Hesawa         1070
# Name: installer_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var_red,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var_red],prefix=var)],axis=1)

# %%
df_comp_val = df_comp_val.drop(labels=[var,var_red],axis=1)

# %% [markdown]
# ### basin

# %%
var = 'basin'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[5:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# Lake Victoria              12871
# Pangani                    11143
# Rufiji                      9987
# Internal                    9642
# Lake Tanganyika             8052
# Wami / Ruvu                 7577
# Lake Nyasa                  6332
# Ruvuma / Southern Coast     5587
# Lake Rukwa                  3059
# Name: basin, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# other    74250
# Name: basin_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var],prefix=var)],axis=1)

# %%
df_comp_val = df_comp_val.drop(labels=[var],axis=1)

# %% [markdown]
# ### region

# %%
var = 'region'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[5:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# Kilimanjaro      5503
# Morogoro         5073
# Njombe           4574
# Arusha           4096
# Mbeya            4056
# Kagera           3884
# Kigoma           3533
# Simiyu           3427
# Pwani            3329
# Ruvuma           3306
# Tanga            3150
# Mwanza           2958
# Dodoma           2780
# Singida          2534
# Shinyanga        2525
# Tabora           2489
# Mara             2450
# Mtwara           2144
# Iringa           2006
# Manyara          1980
# Lindi            1920
# Songwe           1718
# Geita            1548
# Rukwa            1390
# Dar es Salaam    1025
# Katavi            852
# Name: region, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# other          50948
# Kilimanjaro     5503
# Morogoro        5073
# Njombe          4574
# Arusha          4096
# Mbeya           4056
# Name: region_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var_red],prefix=var)],axis=1)

# %%
df_comp_val = df_comp_val.drop(labels=[var,var_red],axis=1)

# %% [markdown]
# ## population

# %%
var = 'population'

df_comp_val[var].hist()
# Out:
# <AxesSubplot:>

# %%
df_comp_val[var+'_bin'] = pd.qcut(df_comp_val[var],4,duplicates='drop').astype(str)

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var+'_bin',hue='status_group')
plt.xticks(rotation=45);

# %%
#df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var+'_bin'],prefix=var)],axis=1)
df_comp_val = df_comp_val.drop(labels=[var+'_bin'],axis=1)

# %% [markdown]
# ### extraction_type_class

# %%
var = 'extraction_type_class'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[5:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# gravity        33263
# handpump       20612
# other           8102
# submersible     7772
# motorpump       3777
# Name: extraction_type_class, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# gravity        33263
# handpump       20612
# other           8826
# submersible     7772
# motorpump       3777
# Name: extraction_type_class_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var_red,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var],prefix=var)],axis=1)

# %%
df_comp_val = df_comp_val.drop(labels=[var,var_red],axis=1)

# %% [markdown]
# ### management

# %%
var = 'management'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[6:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# vwc                 50624
# wug                  8108
# water board          3688
# wua                  3118
# private operator     2504
# parastatal           2229
# Name: management, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# vwc                 50624
# wug                  8108
# other                3979
# water board          3688
# wua                  3118
# private operator     2504
# parastatal           2229
# Name: management_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var_red,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var_red],prefix=var)],axis=1)

# %%
df_comp_val = df_comp_val.drop(labels=[var,var_red],axis=1)

# %% [markdown]
# ### payment_type

# %%
var = 'payment_type'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[6:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# never pay     31712
# per bucket    11266
# monthly       10397
# unknown       10149
# on failure     4842
# annually       4570
# Name: payment_type, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# never pay     31712
# per bucket    11266
# monthly       10397
# unknown       10149
# on failure     4842
# annually       4570
# other          1314
# Name: payment_type_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var_red,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var_red],prefix=var)],axis=1)

# %%
df_comp_val = df_comp_val.drop(labels=[var,var_red],axis=1)

# %% [markdown]
# ### water_quality

# %%
var = 'water_quality'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[3:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# soft       63505
# salty       6082
# unknown     2345
# Name: water_quality, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# soft       63505
# salty       6082
# unknown     2345
# other       2318
# Name: water_quality_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var_red,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var_red],prefix=var)],axis=1)

# %%
df_comp_val = df_comp_val.drop(labels=[var,var_red],axis=1)

# %% [markdown]
# ### quantity

# %%
var = 'quantity'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[4:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# enough          41522
# insufficient    18896
# dry              7782
# seasonal         5075
# Name: quantity, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# enough          41522
# insufficient    18896
# dry              7782
# seasonal         5075
# other             975
# Name: quantity_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var_red,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var_red],prefix=var)],axis=1)

# %%
df_comp_val = df_comp_val.drop(labels=[var,var_red],axis=1)

# %% [markdown]
# ### source

# %%
var = 'source'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[5:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# spring                  21216
# shallow well            21140
# machine dbh             13822
# river                   11964
# rainwater harvesting     2863
# Name: source, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# spring                  21216
# shallow well            21140
# machine dbh             13822
# river                   11964
# other                    3245
# rainwater harvesting     2863
# Name: source_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var_red,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = df_comp_val.drop(labels=[var,var_red],axis=1)

# %% [markdown]
# ### source_class

# %%
var = 'source_class'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[2:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# groundwater    57286
# surface        16617
# Name: source_class, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# groundwater    57286
# surface        16617
# other            347
# Name: source_class_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var_red,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var_red],prefix=var)],axis=1)

# %%
df_comp_val = df_comp_val.drop(labels=[var,var_red],axis=1)

# %% [markdown]
# ### waterpoint_type

# %%
var = 'waterpoint_type'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[4:]
df_comp_val[var][~df_comp_val[var].isin(limited_list.index.to_list())].value_counts()
# Out:
# communal standpipe             35628
# hand pump                      21884
# other                           8010
# communal standpipe multiple     7611
# Name: waterpoint_type, dtype: int64

# %%
df_comp_val[var_red] = df_comp_val[var]

# Reduce number of categorical variables, encoding values with less than 1% prevalence to 'other'
for idx in df_comp_val[df_comp_val[var_red].isin(limited_list.index.to_list())].index.tolist():
    df_comp_val.loc[idx,var_red] = 'other'
    
df_comp_val[var_red].value_counts()
# Out:
# communal standpipe             35628
# hand pump                      21884
# other                           9127
# communal standpipe multiple     7611
# Name: waterpoint_type_reduced, dtype: int64

# %%
plt.figure(figsize=(15,7))

sns.countplot(data=df_comp_val,x=var_red,hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = pd.concat([df_comp_val,pd.get_dummies(df_comp_val[var_red],prefix=var)],axis=1)

# %%
df_comp_val = df_comp_val.drop(labels=[var,var_red],axis=1)

# %% [markdown]
# ### pump_age

# %%
var = 'pump_age'
var_red = var+'_reduced'

limited_list = df_comp_val[var].value_counts()[df_comp_val[var].value_counts().index < 0]
df_comp_val[var].value_counts()[df_comp_val[var].value_counts().index <= 10]
# Out:
#  3.0     3390
#  1.0     2903
#  2.0     2723
#  5.0     2490
#  4.0     2324
#  7.0     1809
#  6.0     1732
#  8.0     1440
#  10.0    1060
#  9.0     1006
#  0.0      729
# -4.0        3
# -5.0        3
# -2.0        2
# -7.0        2
# -1.0        1
# -3.0        1
# Name: pump_age, dtype: int64

# %%
sns.histplot(data=df_comp_val,x=var,hue='status_group',multiple='dodge')
plt.xticks(rotation=45);

# %%
q20 = df_comp_val[var].quantile(0.2)
q40 = df_comp_val[var].quantile(0.4)
q60 = df_comp_val[var].quantile(0.6)
q80 = df_comp_val[var].quantile(0.8)
q100 = df_comp_val[var].quantile(1)

df_comp_val[var+'_bin'] = pd.cut(df_comp_val[var],bins=[0,q20,q40,q60,q80,q100],labels=['0-20','20-40','40-60','60-80','80-100']).astype(str)

# %%
sns.countplot(data=df_comp_val,x=var+'_bin',hue='status_group')
plt.xticks(rotation=45);

# %%
df_comp_val = df_comp_val.drop(labels=[var+'_bin'],axis=1)

# %% [markdown]
# ## Feature Review

# %%
df_comp_val.iloc[:3,:]
# Out:
#       id  amount_tsh  gps_height  longitude  latitude  district_code  \
# 0  69572      6000.0        1390  34.938093 -9.856322              5
# 1   8776         0.0        1399  34.698766 -2.147466              2
# 2  34310        25.0         686  37.460664 -3.821329              4
#
#    population  public_meeting  permit  pump_age  ... quantity_insufficient  \
# 0         109               1       1      12.0  ...                     0
# 1         280               1       1       3.0  ...                     1
# 2         250               1       1       4.0  ...                     0
#
#    quantity_other  quantity_seasonal  source_class_groundwater  \
# 0               0                  0                         1
# 1               0                  0                         0
# 2               0                  0                         0
#
#    source_class_other  source_class_surface  \
# 0                   0                     0
# 1                   0                     1
# 2                   0                     1
#
#    waterpoint_type_communal standpipe  \
# 0                                   1
# 1                                   1
# 2                                   0
#
#    waterpoint_type_communal standpipe multiple  waterpoint_type_hand pump  \
# 0                                            0                          0
# 1                                            0                          0
# 2                                            1                          0
#
#    waterpoint_type_other
# 0                      0
# 1                      0
# 2                      0
#
# [3 rows x 66 columns]

# %%
df_comp_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74250 entries, 0 to 74249
# Data columns (total 66 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   id                                           74250 non-null  int64
#  1   amount_tsh                                   74250 non-null  float64
#  2   gps_height                                   74250 non-null  int64
#  3   longitude                                    74250 non-null  float64
#  4   latitude                                     74250 non-null  float64
#  5   district_code                                74250 non-null  int64
#  6   population                                   74250 non-null  int64
#  7   public_meeting                               74250 non-null  int64
#  8   permit                                       74250 non-null  int64
#  9   pump_age                                     74250 non-null  float64
#  10  status_group                                 59400 non-null  object
#  11  installer_Commu                              74250 non-null  uint8
#  12  installer_DWE                                74250 non-null  uint8
#  13  installer_Government                         74250 non-null  uint8
#  14  installer_RWE                                74250 non-null  uint8
#  15  installer_other                              74250 non-null  uint8
#  16  installer_unknown                            74250 non-null  uint8
#  17  basin_Internal                               74250 non-null  uint8
#  18  basin_Lake Tanganyika                        74250 non-null  uint8
#  19  basin_Lake Victoria                          74250 non-null  uint8
#  20  basin_Pangani                                74250 non-null  uint8
#  21  basin_Rufiji                                 74250 non-null  uint8
#  22  basin_other                                  74250 non-null  uint8
#  23  region_Arusha                                74250 non-null  uint8
#  24  region_Kilimanjaro                           74250 non-null  uint8
#  25  region_Mbeya                                 74250 non-null  uint8
#  26  region_Morogoro                              74250 non-null  uint8
#  27  region_Njombe                                74250 non-null  uint8
#  28  region_other                                 74250 non-null  uint8
#  29  extraction_type_class_gravity                74250 non-null  uint8
#  30  extraction_type_class_handpump               74250 non-null  uint8
#  31  extraction_type_class_motorpump              74250 non-null  uint8
#  32  extraction_type_class_other                  74250 non-null  uint8
#  33  extraction_type_class_rope pump              74250 non-null  uint8
#  34  extraction_type_class_submersible            74250 non-null  uint8
#  35  extraction_type_class_wind-powered           74250 non-null  uint8
#  36  management_other                             74250 non-null  uint8
#  37  management_parastatal                        74250 non-null  uint8
#  38  management_private operator                  74250 non-null  uint8
#  39  management_vwc                               74250 non-null  uint8
#  40  management_water board                       74250 non-null  uint8
#  41  management_wua                               74250 non-null  uint8
#  42  management_wug                               74250 non-null  uint8
#  43  payment_type_annually                        74250 non-null  uint8
#  44  payment_type_monthly                         74250 non-null  uint8
#  45  payment_type_never pay                       74250 non-null  uint8
#  46  payment_type_on failure                      74250 non-null  uint8
#  47  payment_type_other                           74250 non-null  uint8
#  48  payment_type_per bucket                      74250 non-null  uint8
#  49  payment_type_unknown                         74250 non-null  uint8
#  50  water_quality_other                          74250 non-null  uint8
#  51  water_quality_salty                          74250 non-null  uint8
#  52  water_quality_soft                           74250 non-null  uint8
#  53  water_quality_unknown                        74250 non-null  uint8
#  54  quantity_dry                                 74250 non-null  uint8
#  55  quantity_enough                              74250 non-null  uint8
#  56  quantity_insufficient                        74250 non-null  uint8
#  57  quantity_other                               74250 non-null  uint8
#  58  quantity_seasonal                            74250 non-null  uint8
#  59  source_class_groundwater                     74250 non-null  uint8
#  60  source_class_other                           74250 non-null  uint8
#  61  source_class_surface                         74250 non-null  uint8
#  62  waterpoint_type_communal standpipe           74250 non-null  uint8
#  63  waterpoint_type_communal standpipe multiple  74250 non-null  uint8
#  64  waterpoint_type_hand pump                    74250 non-null  uint8
#  65  waterpoint_type_other                        74250 non-null  uint8
# dtypes: float64(4), int64(6), object(1), uint8(55)
# memory usage: 10.1+ MB

# %%
train_index = df_train_val.id.tolist()
test_index = df_test_val.id.tolist()

df_train_val_new = df_comp_val[df_comp_val.id.isin(train_index)]


df_train_val_new.to_csv(data_processed_dir+'training_data_encoded_impv2_geo-corr.csv',index=False)

df_test_val_new = df_comp_val[df_comp_val.id.isin(test_index)]
df_test_val_new.to_csv(data_processed_dir+'test_data_encoded_impv2_geo-corr.csv',index=False)
